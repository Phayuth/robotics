# %%
import os
import sys
wd = os.path.abspath(os.getcwd())
sys.path.append(str(wd))

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# # Single

# %%
path = "/home/yuth/ws_yuthdev/robotics_manipulator/datasave/planner_thesis_data/"
# 0. RRTBase
# 1. RRTStar
# 2. RRTInformed
# 3. RRTStarQuick

# 4. RRTConnect
# 5. RRTStarConnect
# 6. RRTInformedConnect
# 7. RRTStarConnectQuick

# 8. RRTBaseMulti
# 9. RRTStarMulti
# 10. RRTInformedMulti
# 11. RRTStarQuickMulti

# 12. RRTConnectMulti
# 13. RRTStarConnectMulti
# 14. RRTStarConnectQuickMulti

# 15. RRTConnectNoneAgressive - baseline
# 16. RRTConnectNoneAgressiveMulti - baseline

a = pd.read_csv(path + "env_UR5eArmCoppeliaSimAPI_types_Single_planner_2_withlocgap_False_performance.csv").drop('Unnamed: 0', axis=1)
b = pd.read_csv(path + "env_UR5eArmCoppeliaSimAPI_types_Single_planner_4_withlocgap_False_performance.csv").drop('Unnamed: 0', axis=1)
c = pd.read_csv(path + "env_UR5eArmCoppeliaSimAPI_types_Single_planner_15_withlocgap_False_performance.csv").drop('Unnamed: 0', axis=1)
d = pd.read_csv(path + "env_UR5eArmCoppeliaSimAPI_types_Single_planner_5_withlocgap_False_performance.csv").drop('Unnamed: 0', axis=1)
e = pd.read_csv(path + "env_UR5eArmCoppeliaSimAPI_types_Single_planner_6_withlocgap_False_performance.csv").drop('Unnamed: 0', axis=1)

f = pd.read_csv(path + "env_UR5eArmCoppeliaSimAPI_types_Single_planner_4_withlocgap_True_performance.csv").drop('Unnamed: 0', axis=1)
g = pd.read_csv(path + "env_UR5eArmCoppeliaSimAPI_types_Single_planner_15_withlocgap_True_performance.csv").drop('Unnamed: 0', axis=1)
h = pd.read_csv(path + "env_UR5eArmCoppeliaSimAPI_types_Single_planner_5_withlocgap_True_performance.csv").drop('Unnamed: 0', axis=1)

# %% [markdown]
# # Mean

# %%
am = a.mean(axis=0)
bm = b.mean(axis=0)
cm = c.mean(axis=0)
dm = d.mean(axis=0)
em = e.mean(axis=0)
fm = f.mean(axis=0)
gm = g.mean(axis=0)
hm = h.mean(axis=0)

df = pd.concat([am, bm, cm, dm, em, fm, gm, hm], axis=1)
df.rename(
    columns={
        0: "inform",
        1: "connect",
        2: "connect na",
        3: "star connect",
        4: "infrom star connect",
        5: "connect locgap",
        6: "connect na locgap",
        7: "star connect locgap",
    },
    inplace=True,
)
df.T
# Out:
#                      First Cost  First Iteration  Latest Cost  \
# inform                 7.939679          2396.00     7.939679
# connect                6.152467           152.78     5.685101
# connect na             7.917013           215.41     7.207117
# star connect           6.152467           152.78     5.684352
# infrom star connect    6.152467           152.78     5.565598
# connect locgap         6.152467           152.78     5.272748
# connect na locgap      7.917013           215.41     5.787462
# star connect locgap    6.152467           152.78     4.825876
#
#                      Latest Iteration   Run Time  Plan Time  Col.C Time  \
# inform                        2396.00  26.014853  10.508674   15.506178
# connect                        236.72  55.562210  17.971746   37.590464
# connect na                     567.46  49.898440  17.065427   32.833013
# star connect                   236.74  67.316103  29.462154   37.853949
# ...

# %% [markdown]
# # STD

# %%
astd = a.std(axis=0)
bstd = b.std(axis=0)
cstd = c.std(axis=0)
dstd = d.std(axis=0)
estd = e.std(axis=0)
fstd = f.std(axis=0)
gstd = g.std(axis=0)
hstd = h.std(axis=0)

dfs = pd.concat([astd, bstd, cstd, dstd, estd, fstd, gstd, hstd], axis=1)
dfs.rename(
    columns={
        0: "inform",
        1: "connect",
        2: "connect na",
        3: "star connect",
        4: "infrom star connect",
        5: "connect locgap",
        6: "connect na locgap",
        7: "star connect locgap",
    },
    inplace=True,
)
dfs.T
# Out:
#                      First Cost  First Iteration  Latest Cost  \
# inform                      NaN              NaN          NaN
# connect                1.028562        76.830205     0.695116
# connect na             1.309919       110.754173     0.829479
# star connect           1.028562        76.830205     0.694189
# infrom star connect    1.028562        76.830205     0.645689
# connect locgap         1.028562        76.830205     0.595899
# connect na locgap      1.309919       110.754173     0.601670
# star connect locgap    1.028562        76.830205     0.458523
#
#                      Latest Iteration  Run Time  Plan Time  Col.C Time  \
# inform                            NaN  1.077436   0.656839    0.447729
# connect                    305.561483  2.302971   1.127689    1.225445
# connect na                 611.280200  2.608001   1.562911    1.069289
# star connect               305.547616  2.568589   1.666002    0.922435
# ...

# %% [markdown]
# # To thesis

# %%
df = df.T
dfs = dfs.T
df = df.round(2)
dfs = dfs.round(2)

# %%
dfnew = df.copy()
dfnew['First Cost'] = '&$' + df['First Cost'].map(str) + ' \pm ' + dfs['First Cost'].map(str) + '$'
dfnew['First Iteration'] = '&$' + df['First Iteration'].map(str) + ' \pm ' + dfs['First Iteration'].map(str) + '$'
dfnew['Latest Cost'] = '&$' + df['Latest Cost'].map(str) + ' \pm ' + dfs['Latest Cost'].map(str)+ '$'
dfnew['Latest Iteration'] = '&$' + df['Latest Iteration'].map(str) + ' \pm ' + dfs['Latest Iteration'].map(str)+ '$'
dfnew['Run Time'] = '&$' + df['Run Time'].map(str) + ' \pm ' + dfs['Run Time'].map(str)+ '$'
dfnew['Plan Time'] = '&$' + df['Plan Time'].map(str) + ' \pm ' + dfs['Plan Time'].map(str)+ '$'
dfnew['Col.C Time'] = '&$' + df['Col.C Time'].map(str) + ' \pm ' + dfs['Col.C Time'].map(str)+ '$'
dfnew['Node Number'] = '&$' + df['Node Number'].map(str) + ' \pm ' + dfs['Node Number'].map(str)+ '$'
dfnew['Col.C Number'] = '&$' + df['Col.C Number'].map(str) + ' \pm ' + dfs['Col.C Number'].map(str)+ '$'
dfnew
# Out:
#                            First Cost       First Iteration       Latest Cost  \
# inform                &$7.94 \pm nan$     &$2396.0 \pm nan$   &$7.94 \pm nan$
# connect              &$6.15 \pm 1.03$   &$152.78 \pm 76.83$   &$5.69 \pm 0.7$
# connect na           &$7.92 \pm 1.31$  &$215.41 \pm 110.75$  &$7.21 \pm 0.83$
# star connect         &$6.15 \pm 1.03$   &$152.78 \pm 76.83$  &$5.68 \pm 0.69$
# infrom star connect  &$6.15 \pm 1.03$   &$152.78 \pm 76.83$  &$5.57 \pm 0.65$
# connect locgap       &$6.15 \pm 1.03$   &$152.78 \pm 76.83$   &$5.27 \pm 0.6$
# connect na locgap    &$7.92 \pm 1.31$  &$215.41 \pm 110.75$   &$5.79 \pm 0.6$
# star connect locgap  &$6.15 \pm 1.03$   &$152.78 \pm 76.83$  &$4.83 \pm 0.46$
#
#                           Latest Iteration           Run Time  \
# inform                   &$2396.0 \pm nan$  &$26.01 \pm 1.08$
# connect               &$236.72 \pm 305.56$   &$55.56 \pm 2.3$
# connect na            &$567.46 \pm 611.28$   &$49.9 \pm 2.61$
# ...

# %% [markdown]
# # Multi

# %%
path = "/home/yuth/ws_yuthdev/robotics_manipulator/datasave/planner_thesis_data/"
# 0. RRTBase
# 1. RRTStar
# 2. RRTInformed
# 3. RRTStarQuick

# 4. RRTConnect
# 5. RRTStarConnect
# 6. RRTInformedConnect
# 7. RRTStarConnectQuick

# 8. RRTBaseMulti
# 9. RRTStarMulti
# 10. RRTInformedMulti
# 11. RRTStarQuickMulti

# 12. RRTConnectMulti
# 13. RRTStarConnectMulti
# 14. RRTStarConnectQuickMulti

# 15. RRTConnectNoneAgressive - baseline
# 16. RRTConnectNoneAgressiveMulti - baseline

i = pd.read_csv(path + "env_UR5eArmCoppeliaSimAPI_types_Multi_planner_12_withlocgap_False_performance.csv").drop('Unnamed: 0', axis=1)
j = pd.read_csv(path + "env_UR5eArmCoppeliaSimAPI_types_Multi_planner_16_withlocgap_False_performance.csv").drop('Unnamed: 0', axis=1)
k = pd.read_csv(path + "env_UR5eArmCoppeliaSimAPI_types_Multi_planner_13_withlocgap_False_performance.csv").drop('Unnamed: 0', axis=1)

l = pd.read_csv(path + "env_UR5eArmCoppeliaSimAPI_types_Multi_planner_12_withlocgap_True_performance.csv").drop('Unnamed: 0', axis=1)
m = pd.read_csv(path + "env_UR5eArmCoppeliaSimAPI_types_Multi_planner_16_withlocgap_True_performance.csv").drop('Unnamed: 0', axis=1)
n = pd.read_csv(path + "env_UR5eArmCoppeliaSimAPI_types_Multi_planner_13_withlocgap_True_performance.csv").drop('Unnamed: 0', axis=1)

# %%
im = i.mean(axis=0)
jm = j.mean(axis=0)
km = k.mean(axis=0)

lm = l.mean(axis=0)
mm = m.mean(axis=0)
nm = n.mean(axis=0)

df2 = pd.concat([im, jm, km, lm, mm, nm], axis=1)
df2.rename(
    columns={
        0: "cnt multi",
        1: "cnt na multi",
        2: "star cnt multi",
        3: "cnt multi locgap",
        4: "cnt na multi locgap",
        5: "star cnt multi locgap",
    },
    inplace=True,
)
df2.T
# Out:
#                        First Cost  First Iteration  Latest Cost  \
# cnt multi                4.997510           168.40     4.555538
# cnt na multi             6.284201           240.11     5.579743
# star cnt multi           4.997510           168.40     4.554963
# cnt multi locgap         4.997510           168.40     3.903972
# cnt na multi locgap      6.284201           240.11     4.136560
# star cnt multi locgap    4.997510           168.40     3.360581
#
#                        Latest Iteration   Run Time  Plan Time  Col.C Time  \
# cnt multi                        427.85  56.062369  18.066851   37.995518
# cnt na multi                     487.43  49.204926  16.507948   32.696978
# star cnt multi                   427.90  67.306423  29.421164   37.885260
# cnt multi locgap                 536.61  29.066436  14.473076   14.593360
# cnt na multi locgap              543.80  25.246374  14.142937   11.103437
# ...

# %%
istd = i.std(axis=0)
jstd = j.std(axis=0)
kstd = k.std(axis=0)

lstd = l.std(axis=0)
mstd = m.std(axis=0)
nstd = n.std(axis=0)

dfs2 = pd.concat([istd, jstd, kstd, lstd, mstd, nstd], axis=1)
dfs2.rename(
    columns={
        0: "cnt multi",
        1: "cnt na multi",
        2: "star cnt multi",
        3: "cnt multi locgap",
        4: "cnt na multi locgap",
        5: "star cnt multi locgap",
    },
    inplace=True,
)
dfs2.T
# Out:
#                        First Cost  First Iteration  Latest Cost  \
# cnt multi                0.985948        89.556145     0.777489
# cnt na multi             1.288871       115.201790     0.895461
# star cnt multi           0.985948        89.556145     0.777063
# cnt multi locgap         0.985948        89.556145     0.680487
# cnt na multi locgap      1.288871       115.201790     0.663596
# star cnt multi locgap    0.985948        89.556145     0.559966
#
#                        Latest Iteration  Run Time  Plan Time  Col.C Time  \
# cnt multi                    625.141186  2.468452   1.384643    1.119195
# cnt na multi                 505.961616  2.637886   1.621629    1.045008
# star cnt multi               625.125967  3.141347   2.044995    1.109212
# cnt multi locgap             516.815754  4.062108   2.852243    1.327261
# cnt na multi locgap          517.173534  2.394983   2.163511    0.734449
# star cnt multi locgap        687.845105  6.621541   3.947459    3.628485
#
# ...

# %%
df2 = df2.T
dfs2 = dfs2.T
df2 = df2.round(2)
dfs2 = dfs2.round(2)

# %%
dfnew2 = df2.copy()
dfnew2['First Cost'] = '&$' + df2['First Cost'].map(str) + ' \pm ' + dfs2['First Cost'].map(str) + '$'
dfnew2['First Iteration'] = '&$' + df2['First Iteration'].map(str) + ' \pm ' + dfs2['First Iteration'].map(str) + '$'
dfnew2['Latest Cost'] = '&$' + df2['Latest Cost'].map(str) + ' \pm ' + dfs2['Latest Cost'].map(str)+ '$'
dfnew2['Latest Iteration'] = '&$' + df2['Latest Iteration'].map(str) + ' \pm ' + dfs2['Latest Iteration'].map(str)+ '$'
dfnew2['Run Time'] = '&$' + df2['Run Time'].map(str) + ' \pm ' + dfs2['Run Time'].map(str)+ '$'
dfnew2['Plan Time'] = '&$' + df2['Plan Time'].map(str) + ' \pm ' + dfs2['Plan Time'].map(str)+ '$'
dfnew2['Col.C Time'] = '&$' + df2['Col.C Time'].map(str) + ' \pm ' + dfs2['Col.C Time'].map(str)+ '$'
dfnew2['Node Number'] = '&$' + df2['Node Number'].map(str) + ' \pm ' + dfs2['Node Number'].map(str)+ '$'
dfnew2['Col.C Number'] = '&$' + df2['Col.C Number'].map(str) + ' \pm ' + dfs2['Col.C Number'].map(str)+ '$'
dfnew2
# Out:
#                              First Cost      First Iteration  \
# cnt multi               &$5.0 \pm 0.99$   &$168.4 \pm 89.56$
# cnt na multi           &$6.28 \pm 1.29$  &$240.11 \pm 115.2$
# star cnt multi          &$5.0 \pm 0.99$   &$168.4 \pm 89.56$
# cnt multi locgap        &$5.0 \pm 0.99$   &$168.4 \pm 89.56$
# cnt na multi locgap    &$6.28 \pm 1.29$  &$240.11 \pm 115.2$
# star cnt multi locgap   &$5.0 \pm 0.99$   &$168.4 \pm 89.56$
#
#                             Latest Cost      Latest Iteration  \
# cnt multi              &$4.56 \pm 0.78$  &$427.85 \pm 625.14$
# cnt na multi            &$5.58 \pm 0.9$  &$487.43 \pm 505.96$
# star cnt multi         &$4.55 \pm 0.78$   &$427.9 \pm 625.13$
# cnt multi locgap        &$3.9 \pm 0.68$  &$536.61 \pm 516.82$
# cnt na multi locgap    &$4.14 \pm 0.66$   &$543.8 \pm 517.17$
# star cnt multi locgap  &$3.36 \pm 0.56$  &$2321.2 \pm 687.85$
#
#                                 Run Time          Plan Time  \
# ...
